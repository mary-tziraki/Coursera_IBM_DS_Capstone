# %% [markdown]
# ## Week_1 Capstone Project

# %% [markdown]
# ###### This is notebook will be mainly used for the Capstone project as part of the Data Science courses provided by Coursera and IBM

# %%
import pandas as pd
import numpy as np
print("Pandas and Nympy are imported")
# Out:
# Pandas and Nympy are imported

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
